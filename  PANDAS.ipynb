# %%
 import pandas as pd

# %%
df=pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
 df.columns #NAMES OF COLUMNS
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(df.Name[1])
# Out:
# Ivysaur

# %%
print(df[['Name','Type 1','HP']]) #PRINT WANTED COLUMNS
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
df.iloc[1]             #TO PRINBT ROWS
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
df.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
df.iloc[:,:]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.iloc[0:1,:]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
df.loc[0:1,0:1] # THAT IS WHY WE USE ILOC
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-3303a6535856> in <module>
# ----> 1 df.loc[0:1,0:1] # THAT IS WHY WE USE ILOC
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# ...

# %%
for index, row in df.iterrows():     #IT WILL PRINT ROW BY ROW
    print(index,row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
for index, row in df.iterrows():     #IT WILL PRINT ROW BY ROW (Name)
    print(index,row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.loc[df['Type 1']=="Fire"] #LOC IS MIANLY USED FOR VARIABLES
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP']) # GIVES PRIORITY TO FIRST TYPE1 AND THEN HP
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP'],ascending="False") # GIVES PRIORITY TO FIRST TYPE1 AND THEN HP by DESENDING
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP'],ascending=(1,0)) #FIRST ASENDING, THEN DESENDING
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
 df['total']=df['HP']+df['Attack']+df['Defense'] #ADDING COLUMNS

# %%
 df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  total
# 0         65       65     45           1      False    143
# ...

# %%
df=df.drop(columns='total') #REMOVES COLOUMN

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# BELOW [:.4:10] MEANS FROM 4 UPTO 10 LIKE 4+5+6+7+8+9 THATS IT DONT ADD 10

# %%
 df['total']=df.iloc[:,4:10].sum(axis=1) # IF AXIS=1 ADDS HORIZENTALLY 
                                        # IF AXIS=0 ADDS VERTICALLY

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False  208.0  45
# 1      2                Ivysaur    Grass  Poison      False  265.0  60
# 2      3               Venusaur    Grass  Poison      False  345.0  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  425.0  80
# 4      4             Charmander     Fire     NaN      False  194.0  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True  401.0  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True  481.0  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  401.0  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  471.0  80
# 799  721              Volcanion     Fire   Water       True  441.0  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %% [markdown]
# #REARRANGING COLUMNS
# FIRST WE MAKE THEM TO LIST AND WE ADD THEM DF

# %%
cols=list(df.columns)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.to_csv('modified.csv',index=False)

# %%
df.to_excel('modified.xlsx')

# %%
df.to_csv('modify.csv',index=False,sep='\t') #WE GET TAB SEPERATED VALUES

# %% [markdown]
# FILTERING

# %%
df.loc[(df['Type 1']=="Grass") & (df['Type 2']=='Dark')] #FILTERING
# Out:
#        #      Name Type 1 Type 2  Generation  Legendary  total  HP  Attack  \
# 297  274   Nuzleaf  Grass   Dark           3      False  240.0  70      70
# 298  275   Shiftry  Grass   Dark           3      False  340.0  90     100
# 363  332  Cacturne  Grass   Dark           3      False  360.0  70     115
#
#      Defense  Sp. Atk  Sp. Def  Speed
# 297       40       60       40     60
# 298       60       90       60     80
# 363       60      115       60     55

# %%
df.loc[(df['Type 1']=="Grass") | (df['Type 2']=='Dark')] # OR OPERATION
# Out:
#        #                   Name    Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur     Grass  Poison           1      False
# 1      2                Ivysaur     Grass  Poison           1      False
# 2      3               Venusaur     Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur     Grass  Poison           1      False
# 48    43                 Oddish     Grass  Poison           1      False
# ..   ...                    ...       ...     ...         ...        ...
# 726  658               Greninja     Water    Dark           6      False
# 740  672                 Skiddo     Grass     NaN           6      False
# 741  673                 Gogoat     Grass     NaN           6      False
# 743  675                Pangoro  Fighting    Dark           6      False
# 798  720     HoopaHoopa Unbound   Psychic    Dark           6       True
#
#      total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
new_df=df.loc[(df['Type 1']=="Grass") & (df['Type 2']=='Dark')& (df['HP']>50)]
new_df #AS WE SEE BELOW TH INDEX IN FIXED TO CHANGE IT ACCORDING TO DATAFRAME
# Out:
#        #      Name Type 1 Type 2  Generation  Legendary  total  HP  Attack  \
# 297  274   Nuzleaf  Grass   Dark           3      False  240.0  70      70
# 298  275   Shiftry  Grass   Dark           3      False  340.0  90     100
# 363  332  Cacturne  Grass   Dark           3      False  360.0  70     115
#
#      Defense  Sp. Atk  Sp. Def  Speed
# 297       40       60       40     60
# 298       60       90       60     80
# 363       60      115       60     55

# %%
new_df=new_df.reset_index()

# %%
new_df #(SO INDEX CHANGED)
# Out:
#    index    #      Name Type 1 Type 2  Generation  Legendary  total  HP  \
# 0    297  274   Nuzleaf  Grass   Dark           3      False  240.0  70
# 1    298  275   Shiftry  Grass   Dark           3      False  340.0  90
# 2    363  332  Cacturne  Grass   Dark           3      False  360.0  70
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      70       40       60       40     60
# 1     100       60       90       60     80
# 2     115       60      115       60     55

# %%
new_df.to_csv('testing.csv', index=False,sep='\t') #FILTERING AND ENTERING INTO NEW DATA FRAME CONVERTING TO CSV FIOLE

# %% [markdown]
# TO FILTER IMPORT RE

# %%
import re

# %%
df.loc[df['Name'].str.contains('Mega')] # string contains mega which means checks the string of name
# Out:
#        #                       Name    Type 1    Type 2  Generation  \
# 3      3      VenusaurMega Venusaur     Grass    Poison           1
# 7      6  CharizardMega Charizard X      Fire    Dragon           1
# 8      6  CharizardMega Charizard Y      Fire    Flying           1
# 12     9    BlastoiseMega Blastoise     Water       NaN           1
# 19    15      BeedrillMega Beedrill       Bug    Poison           1
# 23    18        PidgeotMega Pidgeot    Normal    Flying           1
# 71    65      AlakazamMega Alakazam   Psychic       NaN           1
# 87    80        SlowbroMega Slowbro     Water   Psychic           1
# 102   94          GengarMega Gengar     Ghost    Poison           1
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN           1
# 137  127          PinsirMega Pinsir       Bug    Flying           1
# 141  130      GyaradosMega Gyarados     Water      Dark           1
# 154  142  AerodactylMega Aerodactyl      Rock    Flying           1
# ...

# %%
 df.loc[~df['Name'].str.contains('Mega')] # HERE ~ ACTS AS NOT
# Out:
#        #                 Name   Type 1  Type 2  Generation  Legendary  total  \
# 0      1            Bulbasaur    Grass  Poison           1      False  208.0
# 1      2              Ivysaur    Grass  Poison           1      False  265.0
# 2      3             Venusaur    Grass  Poison           1      False  345.0
# 4      4           Charmander     Fire     NaN           1      False  194.0
# 5      5           Charmeleon     Fire     NaN           1      False  260.0
# ..   ...                  ...      ...     ...         ...        ...    ...
# 794  718     Zygarde50% Forme   Dragon  Ground           6       True  411.0
# 795  719              Diancie     Rock   Fairy           6       True  401.0
# 797  720  HoopaHoopa Confined  Psychic   Ghost           6       True  401.0
# 798  720   HoopaHoopa Unbound  Psychic    Dark           6       True  471.0
# 799  721            Volcanion     Fire   Water           6       True  441.0
#
# ...

# %%
 df.loc[df['Type 1'].str.contains('grass|fire',flags=re.I,regex=True)] # flags=re represents don't consider upper or lower cases
# Out:
#        #                   Name Type 1  Type 2  Generation  Legendary  total  \
# 0      1              Bulbasaur  Grass  Poison           1      False  208.0
# 1      2                Ivysaur  Grass  Poison           1      False  265.0
# 2      3               Venusaur  Grass  Poison           1      False  345.0
# 3      3  VenusaurMega Venusaur  Grass  Poison           1      False  425.0
# 4      4             Charmander   Fire     NaN           1      False  194.0
# ..   ...                    ...    ...     ...         ...        ...    ...
# 735  667                 Litleo   Fire  Normal           6      False  243.0
# 736  668                 Pyroar   Fire  Normal           6      False  335.0
# 740  672                 Skiddo  Grass     NaN           6      False  241.0
# 741  673                 Gogoat  Grass     NaN           6      False  382.0
# 799  721              Volcanion   Fire   Water           6       True  441.0
#
# ...

# %%
df.loc[df['Type 1']=='Fire','Type 1']="flame" # TO CHANGE ANY ELEMENT IN DATA FRAME
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander    flame     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion    flame   Water           6       True
#
#      total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.loc[df['Type 1']=='flame','Legendary']='True' # THIS CHANGES WHICH TYPE1 IS FLAME CHANGES ITS LEGENDARY VALUES TO TRUE

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Generation Legendary  total  \
# 0      1              Bulbasaur    Grass  Poison           1     False  208.0
# 1      2                Ivysaur    Grass  Poison           1     False  265.0
# 2      3               Venusaur    Grass  Poison           1     False  345.0
# 3      3  VenusaurMega Venusaur    Grass  Poison           1     False  425.0
# 4      4             Charmander    flame     NaN           1      True  194.0
# ..   ...                    ...      ...     ...         ...       ...    ...
# 795  719                Diancie     Rock   Fairy           6      True  401.0
# 796  719    DiancieMega Diancie     Rock   Fairy           6      True  481.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6      True  401.0
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6      True  471.0
# 799  721              Volcanion    flame   Water           6      True  441.0
#
# ...

# %%
df.loc[df['Type 1']=='flame','Name','HP']='ju','10' #ERROR BECAUSE WE ARE MULTIPLE VALUES SO WE NEED TO USE LIST THAT IS TWO SQ.BRACKETS
df
# Out:
# C:\Users\Personal\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     635         try:
# --> 636             return self._convert_to_indexer(key, axis=0, is_setter=True)
#     637         except TypeError as e:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, key, axis, is_setter)
#    1211                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
 df.loc[df['Type 1']=='flame',['Name','HP','Legendary']]='ju','10','jai'
 df
# Out:
#        #                   Name   Type 1  Type 2  Generation Legendary  total  \
# 0      1              Bulbasaur    Grass  Poison           1     False  208.0
# 1      2                Ivysaur    Grass  Poison           1     False  265.0
# 2      3               Venusaur    Grass  Poison           1     False  345.0
# 3      3  VenusaurMega Venusaur    Grass  Poison           1     False  425.0
# 4      4                     ju    flame     NaN           1       jai  194.0
# ..   ...                    ...      ...     ...         ...       ...    ...
# 795  719                Diancie     Rock   Fairy           6      True  401.0
# 796  719    DiancieMega Diancie     Rock   Fairy           6      True  481.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6      True  401.0
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6      True  471.0
# 799  721                     ju    flame   Water           6       jai  441.0
#
# ...

# %%
df.loc[df['Type 1']=='flame',['Name','HP']]='ju' # IT IS LIKE CONDITION PASSING
df
# Out:
#        #                   Name   Type 1  Type 2  Generation Legendary  total  \
# 0      1              Bulbasaur    Grass  Poison           1     False  208.0
# 1      2                Ivysaur    Grass  Poison           1     False  265.0
# 2      3               Venusaur    Grass  Poison           1     False  345.0
# 3      3  VenusaurMega Venusaur    Grass  Poison           1     False  425.0
# 4      4                     ju    flame     NaN           1       jai  194.0
# ..   ...                    ...      ...     ...         ...       ...    ...
# 795  719                Diancie     Rock   Fairy           6      True  401.0
# 796  719    DiancieMega Diancie     Rock   Fairy           6      True  481.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6      True  401.0
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6      True  471.0
# 799  721                     ju    flame   Water           6       jai  441.0
#
# ...

# %%
df.to_csv('txt.csv')

# %%
# THATS ENOUGH LETS READ ORIGINAL FILE
pd.read_csv('modified.csv')
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.iloc[0:4,0:2]
# Out:
#    #                   Name
# 0  1              Bulbasaur
# 1  2                Ivysaur
# 2  3               Venusaur
# 3  3  VenusaurMega Venusaur

# %%
#WE USE USE [[]]"DOUBLE SQ.BRACKETS WHICH IS LIST"
df.iloc[[:,:]]#GIVES ERROE
# Out:
#   File "<ipython-input-149-9214631f5089>", line 2
#     df.iloc[[:,:]]#GIVES ERROE
#              ^
# SyntaxError: invalid syntax

# %%
df.iloc[[2]]
# Out:
#    #      Name Type 1  Type 2  Generation Legendary  total  HP  Attack  \
# 2  3  Venusaur  Grass  Poison           1     False  345.0  80      82
#
#    Defense  Sp. Atk  Sp. Def  Speed
# 2       83      100      100     80

# %% [markdown]
# # AGGREGATE STATISTICS (groupby)

# %%
df=pd.read_csv('modified.csv')
df.groupby(['Type 1']).mean() # groupby([]).mean() gives the mean of specific
# Out:
#                    #  Generation  Legendary       total         HP  \
# Type 1
# Bug       334.492754    3.217391   0.000000  252.449275  56.884058
# Dark      461.354839    4.032258   0.064516  300.129032  66.806452
# Dragon    474.375000    3.875000   0.375000  379.031250  83.312500
# Electric  363.500000    3.272727   0.090909  285.295455  59.795455
# Fairy     449.529412    4.117647   0.058824  279.941176  74.117647
# Fighting  363.851852    3.370370   0.000000  285.666667  69.851852
# Fire      327.403846    3.211538   0.096154  311.519231  69.903846
# Flying    677.750000    5.500000   0.500000  310.500000  70.750000
# Ghost     486.500000    4.187500   0.062500  298.812500  64.437500
# Grass     344.871429    3.357143   0.042857  288.828571  67.271429
# Ground    356.281250    3.156250   0.125000  310.968750  73.781250
# Ice       423.541667    3.541667   0.083333  293.791667  72.000000
# Normal    319.173469    3.051020   0.020408  266.428571  77.275510
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense') #SORTING values by defense
# Out:
#                    #  Generation  Legendary       total         HP  \
# Type 1
# Normal    319.173469    3.051020   0.020408  266.428571  77.275510
# Fairy     449.529412    4.117647   0.058824  279.941176  74.117647
# Fighting  363.851852    3.370370   0.000000  285.666667  69.851852
# Flying    677.750000    5.500000   0.500000  310.500000  70.750000
# Electric  363.500000    3.272727   0.090909  285.295455  59.795455
# Psychic   380.807018    3.385965   0.245614  308.421053  70.631579
# Fire      327.403846    3.211538   0.096154  311.519231  69.903846
# Poison    251.785714    2.535714   0.000000  271.178571  67.250000
# Dark      461.354839    4.032258   0.064516  300.129032  66.806452
# Bug       334.492754    3.217391   0.000000  252.449275  56.884058
# Grass     344.871429    3.357143   0.042857  288.828571  67.271429
# Ice       423.541667    3.541667   0.083333  293.791667  72.000000
# Water     303.089286    2.857143   0.035714  294.008929  72.062500
# ...

# %%
df.sort_values('total') #NORMAL SORTING BY TOTAL
# Out:
#        #                   Name    Type 1    Type 2  Generation  Legendary  \
# 424  383  GroudonPrimal Groudon    Ground      Fire           3       True
# 426  384  RayquazaMega Rayquaza    Dragon    Flying           3       True
# 163  150    MewtwoMega Mewtwo X   Psychic  Fighting           1       True
# 164  150    MewtwoMega Mewtwo Y   Psychic       NaN           1       True
# 422  382    KyogrePrimal Kyogre     Water       NaN           3       True
# ..   ...                    ...       ...       ...         ...        ...
# 303  280                  Ralts   Psychic     Fairy           3      False
# 206  191                Sunkern     Grass       NaN           2      False
# 186  172                  Pichu  Electric       NaN           2      False
# 139  129               Magikarp     Water       NaN           1      False
# 381  349                 Feebas     Water       NaN           3      False
#
#      total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
df.sort_values('total',ascending=False) # IF WE WANT DECREASING ORDER
# Out:
#        #                   Name    Type 1    Type 2  Generation  Legendary  \
# 424  383  GroudonPrimal Groudon    Ground      Fire           3       True
# 426  384  RayquazaMega Rayquaza    Dragon    Flying           3       True
# 163  150    MewtwoMega Mewtwo X   Psychic  Fighting           1       True
# 164  150    MewtwoMega Mewtwo Y   Psychic       NaN           1       True
# 422  382    KyogrePrimal Kyogre     Water       NaN           3       True
# ..   ...                    ...       ...       ...         ...        ...
# 303  280                  Ralts   Psychic     Fairy           3      False
# 206  191                Sunkern     Grass       NaN           2      False
# 186  172                  Pichu  Electric       NaN           2      False
# 139  129               Magikarp     Water       NaN           1      False
# 381  349                 Feebas     Water       NaN           3      False
#
#      total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
 df.groupby(['Type 1']).sum()
# Out:
#               #  Generation  Legendary    total    HP  Attack  Defense  \
# Type 1
# Bug       23080         222          0  17419.0  3925    4897     4880
# Dark      14302         125          2   9304.0  2071    2740     2177
# Dragon    15180         124         12  12129.0  2666    3588     2764
# Electric  15994         144          4  12553.0  2631    3040     2917
# Fairy      7642          70          1   4759.0  1260    1046     1117
# Fighting   9824          91          0   7713.0  1886    2613     1780
# Fire      17025         167          5  16199.0  3635    4408     3524
# Flying     2711          22          2   1242.0   283     315      265
# Ghost     15568         134          2   9562.0  2062    2361     2598
# Grass     24141         235          3  20218.0  4709    5125     4956
# Ground    11401         101          4   9951.0  2361    3064     2715
# Ice       10165          85          2   7051.0  1728    1746     1714
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Generation  Legendary  total   HP  Attack  \
# Type 1
# Bug        69    69      52          69         69     69   69      69
# Dark       31    31      21          31         31     31   31      31
# Dragon     32    32      21          32         32     32   32      32
# Electric   44    44      17          44         44     44   44      44
# Fairy      17    17       2          17         17     17   17      17
# Fighting   27    27       7          27         27     27   27      27
# Fire       52    52      24          52         52     52   52      52
# Flying      4     4       2           4          4      4    4       4
# Ghost      32    32      22          32         32     32   32      32
# Grass      70    70      37          70         70     70   70      70
# Ground     32    32      19          32         32     32   32      32
# Ice        24    24      11          24         24     24   24      24
# ...

# %%
new_df=df.groupby(['Type 1']).count().sort_values('Defense')

# %%
df.drop()
# Out:
#             #  Name  Type 2  Generation  Legendary  total   HP  Attack  \
# Type 1
# Flying      4     4       2           4          4      4    4       4
# Fairy      17    17       2          17         17     17   17      17
# Ice        24    24      11          24         24     24   24      24
# Fighting   27    27       7          27         27     27   27      27
# Steel      27    27      22          27         27     27   27      27
# Poison     28    28      13          28         28     28   28      28
# Dark       31    31      21          31         31     31   31      31
# Ghost      32    32      22          32         32     32   32      32
# Dragon     32    32      21          32         32     32   32      32
# Ground     32    32      19          32         32     32   32      32
# Electric   44    44      17          44         44     44   44      44
# Rock       44    44      35          44         44     44   44      44
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-26a18ec196dd> in <module>
# ----> 1 df.drop('column[2]')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
new_df
# Out:
#             #  Name  Type 2  Generation  Legendary  total   HP  Attack  \
# Type 1
# Flying      4     4       2           4          4      4    4       4
# Fairy      17    17       2          17         17     17   17      17
# Ice        24    24      11          24         24     24   24      24
# Fighting   27    27       7          27         27     27   27      27
# Steel      27    27      22          27         27     27   27      27
# Poison     28    28      13          28         28     28   28      28
# Dark       31    31      21          31         31     31   31      31
# Ghost      32    32      22          32         32     32   32      32
# Dragon     32    32      21          32         32     32   32      32
# Ground     32    32      19          32         32     32   32      32
# Electric   44    44      17          44         44     44   44      44
# Rock       44    44      35          44         44     44   44      44
# ...

# %%
new_df.drop(new_df.index[0:2]) # DELETING ROWS IN DATA FRAME
# Out:
#             #  Name  Type 2  Generation  Legendary  total   HP  Attack  \
# Type 1
# Ice        24    24      11          24         24     24   24      24
# Fighting   27    27       7          27         27     27   27      27
# Steel      27    27      22          27         27     27   27      27
# Poison     28    28      13          28         28     28   28      28
# Dark       31    31      21          31         31     31   31      31
# Ghost      32    32      22          32         32     32   32      32
# Dragon     32    32      21          32         32     32   32      32
# Ground     32    32      19          32         32     32   32      32
# Electric   44    44      17          44         44     44   44      44
# Rock       44    44      35          44         44     44   44      44
# Fire       52    52      24          52         52     52   52      52
# Psychic    57    57      19          57         57     57   57      57
# ...

# %%
new_df['hey']=1 #ADDING NEW COLUMN

# %%
new_df
# Out:
#             #  Name  Type 2  Generation  Legendary  total   HP  Attack  \
# Type 1
# Flying      4     4       2           4          4      4    4       4
# Fairy      17    17       2          17         17     17   17      17
# Ice        24    24      11          24         24     24   24      24
# Fighting   27    27       7          27         27     27   27      27
# Steel      27    27      22          27         27     27   27      27
# Poison     28    28      13          28         28     28   28      28
# Dark       31    31      21          31         31     31   31      31
# Ghost      32    32      22          32         32     32   32      32
# Dragon     32    32      21          32         32     32   32      32
# Ground     32    32      19          32         32     32   32      32
# Electric   44    44      17          44         44     44   44      44
# Rock       44    44      35          44         44     44   44      44
# ...

# %%
df.groupby(['Type 1','Type 2']).count()
# Out:
#                   #  Name  Generation  Legendary  total  HP  Attack  Defense  \
# Type 1 Type 2
# Bug    Electric   2     2           2          2      2   2       2        2
#        Fighting   2     2           2          2      2   2       2        2
#        Fire       2     2           2          2      2   2       2        2
#        Flying    14    14          14         14     14  14      14       14
#        Ghost      1     1           1          1      1   1       1        1
# ...              ..   ...         ...        ...    ...  ..     ...      ...
# Water  Ice        3     3           3          3      3   3       3        3
#        Poison     3     3           3          3      3   3       3        3
#        Psychic    5     5           5          5      5   5       5        5
#        Rock       4     4           4          4      4   4       4        4
#        Steel      1     1           1          1      1   1       1        1
#
# ...

# %%
df.groupby(level=0).mean()
# Out:
#        #  Generation  Legendary  total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1           1      False  208.0  45      49       49       65       65
# 1      2           1      False  265.0  60      62       63       80       80
# 2      3           1      False  345.0  80      82       83      100      100
# 3      3           1      False  425.0  80     100      123      122      120
# 4      4           1      False  194.0  39      52       43       60       50
# ..   ...         ...        ...    ...  ..     ...      ...      ...      ...
# 795  719           6       True  401.0  50     100      150      100      150
# 796  719           6       True  481.0  50     160      110      160      110
# 797  720           6       True  401.0  80     110       60      150      130
# 798  720           6       True  471.0  80     160       60      170      130
# 799  721           6       True  441.0  80     110      120      130       90
#
#      Speed
# 0       45
# ...
